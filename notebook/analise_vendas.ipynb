# %% [markdown]
# **Passo a Passo de solução do Desafio**

# %%
# Lógica de programação

# Passo 0 - Entender o desafio que você quer resolver

# Passo 1 - Percorrer todos os arquivos da pasta base de dados (Pasta Vendas)

# Passo 2 - Importar as bases de dados de vendas

# Passo 3 - Tratar / Compilar as bases de dados

# Passo 4 - Calcular o produto mais vendido (em quantidade)

# Passo 5 - Calcular o produto que mais faturou (em faturamento)

# Passo 6 - Calcular a loja/cidade que mais vendeu (em faturamento) - criar um gráfico/dashboard

# %%
# Passo 1 - Percorrer todos os arquivos da pasta base de dados (Pasta Vendas)
import os

lista_arquivo = os.listdir(r"D:\Projetos\Github\Python\analise_vendas_varejo\dados\relatorios_vendas_devolucoes")
print(lista_arquivo)
# Out:
# ['devolucoes_belo_horizonte.csv', 'devolucoes_curitiba.csv', 'devolucoes_fortaleza.csv', 'devolucoes_goias.csv', 'devolucoes_porto_alegre.csv', 'devolucoes_recife.csv', 'devolucoes_rio_de_janeiro.csv', 'devolucoes_salvador.csv', 'devolucoes_sao_paulo.csv', 'vendas_belo_horizonte.csv', 'vendas_curitiba.csv', 'vendas_fortaleza.csv', 'vendas_goias.csv', 'vendas_porto_alegre.csv', 'vendas_recife.csv', 'vendas_rio_de_janeiro.csv', 'vendas_salvador.csv', 'vendas_sao_paulo.csv']

# %%
# Passo 2 - Importar as bases de dados de vendas
for arquivo in lista_arquivo:
    #print(arquivo)
    print(f"D:/Projetos/Github/Python/analise_vendas_varejo/dados/relatorios_vendas_devolucoes/{arquivo}")
# Out:
# D:/Projetos/Github/Python/analise_vendas_varejo/dados/relatorios_vendas_devolucoes/devolucoes_belo_horizonte.csv
# D:/Projetos/Github/Python/analise_vendas_varejo/dados/relatorios_vendas_devolucoes/devolucoes_curitiba.csv
# D:/Projetos/Github/Python/analise_vendas_varejo/dados/relatorios_vendas_devolucoes/devolucoes_fortaleza.csv
# D:/Projetos/Github/Python/analise_vendas_varejo/dados/relatorios_vendas_devolucoes/devolucoes_goias.csv
# D:/Projetos/Github/Python/analise_vendas_varejo/dados/relatorios_vendas_devolucoes/devolucoes_porto_alegre.csv
# D:/Projetos/Github/Python/analise_vendas_varejo/dados/relatorios_vendas_devolucoes/devolucoes_recife.csv
# D:/Projetos/Github/Python/analise_vendas_varejo/dados/relatorios_vendas_devolucoes/devolucoes_rio_de_janeiro.csv
# D:/Projetos/Github/Python/analise_vendas_varejo/dados/relatorios_vendas_devolucoes/devolucoes_salvador.csv
# D:/Projetos/Github/Python/analise_vendas_varejo/dados/relatorios_vendas_devolucoes/devolucoes_sao_paulo.csv
# D:/Projetos/Github/Python/analise_vendas_varejo/dados/relatorios_vendas_devolucoes/vendas_belo_horizonte.csv
# D:/Projetos/Github/Python/analise_vendas_varejo/dados/relatorios_vendas_devolucoes/vendas_curitiba.csv
# D:/Projetos/Github/Python/analise_vendas_varejo/dados/relatorios_vendas_devolucoes/vendas_fortaleza.csv
# D:/Projetos/Github/Python/analise_vendas_varejo/dados/relatorios_vendas_devolucoes/vendas_goias.csv
# D:/Projetos/Github/Python/analise_vendas_varejo/dados/relatorios_vendas_devolucoes/vendas_porto_alegre.csv
# D:/Projetos/Github/Python/analise_vendas_varejo/dados/relatorios_vendas_devolucoes/vendas_recife.csv
# D:/Projetos/Github/Python/analise_vendas_varejo/dados/relatorios_vendas_devolucoes/vendas_rio_de_janeiro.csv
# D:/Projetos/Github/Python/analise_vendas_varejo/dados/relatorios_vendas_devolucoes/vendas_salvador.csv
# D:/Projetos/Github/Python/analise_vendas_varejo/dados/relatorios_vendas_devolucoes/vendas_sao_paulo.csv

# %%
# Passo 3 - Tratar / Compilar as bases de dados

# %%
# Passo 4 - Calcular o produto mais vendido (em quantidade)

# %%
# Passo 5 - Calcular o produto que mais faturou (em faturamento)

# %%
# Passo 6 - Calcular a loja/cidade que mais vendeu (em faturamento) - criar um gráfico/dashboard
